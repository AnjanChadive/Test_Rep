# %% [markdown]
# # 'My Jupiter Notebook on IBM Watson Studio'

# %% [markdown]
# ## Anjan Chadive
#         Data Analyst & Scientist

# %% [markdown]
# *Im interested in Data Science because I always wanted to integrate finance profession with analysis through machine learning and modelling*

# %% [markdown]
# ### The code in the following cell executes to prints a statement "Hello! World"

# %%
print("Hello! World")
# Out:
# Hello! World

# %% [markdown]
# * [https://in.linkedin.com/in/anjanchadive]
#
# * `this is a code syntax to highlight the text`
#
# * ~~ This is a code syntax to strike through the text ~~
